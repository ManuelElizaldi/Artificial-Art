# %%
import requests
import pandas as pd
from PIL import Image
from io import BytesIO
from hdfs import InsecureClient

# %% [markdown]
# ## Art Institute of Chicago API - Exploration

# %%
# Getting the full list of artworks from this url
url = 'https://api.artic.edu/api/v1/artworks'
r = requests.get(url)
r = r.json()

# %%
df = pd.DataFrame()
for i in range(1,1001):
    r = requests.get(url = f'https://api.artic.edu/api/v1/artworks?page={i}&limit=100').json()
    r = pd.json_normalize(r, ['data'])
    df = df.append(r, ignore_index=True) # type: ignore

df.head(5)
# Out:
#        id api_model                                      api_link  is_boosted  \
# 0  208143  artworks  https://api.artic.edu/api/v1/artworks/208143       False
# 1  117475  artworks  https://api.artic.edu/api/v1/artworks/117475       False
# 2  146866  artworks  https://api.artic.edu/api/v1/artworks/146866       False
# 3   60561  artworks   https://api.artic.edu/api/v1/artworks/60561       False
# 4   88348  artworks   https://api.artic.edu/api/v1/artworks/88348       False
#
#                                          title alt_titles  \
# 0                               Library Ladder       None
# 1                                   Punch Bowl       None
# 2                                     Armchair       None
# 3                                         Desk       None
# 4  Vestment (For a First-degree Taoist Priest)       None
#
#   main_reference_number  has_not_been_viewed_much boost_rank date_start  ...  \
# 0                2011.2                     False        NaN       1782  ...
# 1                1950.3                     False        NaN       1789  ...
# 2              1997.334                     False        NaN       1867  ...
# 3              1947.409                      True        NaN       1755  ...
# 4              1907.322                      True        NaN       1793  ...
#
#   thumbnail.height                                 thumbnail.alt_text color.h  \
# 0           2250.0                 A work made of mahogany and brass.     8.0
# 1           2229.0                          A work made of porcelain.    37.0
# 2           2250.0  A work made of mahogany, purpleheart, ebony, h...   346.0
# 3           2250.0  A work made of wood, walnut and pine, bronze m...   220.0
# 4           2250.0  A work made of silk, warp-float faced 7:1 sati...   319.0
#
#   color.l color.s color.percentage color.population color  \
# 0    37.0    15.0         0.039788            377.0   NaN
# 1    64.0    57.0         0.009854             52.0   NaN
# 2    32.0    61.0         0.001797             16.0   NaN
# 3    48.0    20.0         0.002815             15.0   NaN
# 4    16.0     7.0         0.024036            139.0   NaN
#
#   suggest_autocomplete_boosted thumbnail
# 0                          NaN       NaN
# 1                          NaN       NaN
# 2                          NaN       NaN
# 3                          NaN       NaN
# 4                          NaN       NaN
#
# [5 rows x 105 columns]

# %%
# checkpoint
#df.to_csv(r'C:\Users\Manuel Elizaldi\Desktop\Learning-Testing\Artificial-Art\Resources\chicago_art.csv')
df = pd.read_csv(r'C:\Users\Manuel Elizaldi\Desktop\Learning-Testing\Artificial-Art\Resources\chicago_art.csv')
df.head(5)
# Out:
# c:\Users\Manuel Elizaldi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,3,7,8,9,10,13,25,27,28,29,30,31,32,34,35,36,37,38,39,40,41,42,44,46,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        id api_model                                      api_link is_boosted  \
# 0  208143  artworks  https://api.artic.edu/api/v1/artworks/208143      False
# 1  117475  artworks  https://api.artic.edu/api/v1/artworks/117475      False
# 2  146866  artworks  https://api.artic.edu/api/v1/artworks/146866      False
# 3   60561  artworks   https://api.artic.edu/api/v1/artworks/60561      False
# 4   88348  artworks   https://api.artic.edu/api/v1/artworks/88348      False
#
#                                          title alt_titles  \
# 0                               Library Ladder        NaN
# 1                                   Punch Bowl        NaN
# 2                                     Armchair        NaN
# 3                                         Desk        NaN
# 4  Vestment (For a First-degree Taoist Priest)        NaN
#
#   main_reference_number has_not_been_viewed_much boost_rank date_start  ...  \
# 0                2011.2                    False        NaN       1782  ...
# 1                1950.3                    False        NaN       1789  ...
# 2              1997.334                    False        NaN       1867  ...
# 3              1947.409                     True        NaN       1755  ...
# 4              1907.322                     True        NaN       1793  ...
#
#   thumbnail.height                                 thumbnail.alt_text color.h  \
# 0           2250.0                 A work made of mahogany and brass.     8.0
# 1           2229.0                          A work made of porcelain.    37.0
# 2           2250.0  A work made of mahogany, purpleheart, ebony, h...   346.0
# 3           2250.0  A work made of wood, walnut and pine, bronze m...   220.0
# 4           2250.0  A work made of silk, warp-float faced 7:1 sati...   319.0
#
#   color.l color.s color.percentage color.population color  \
# 0    37.0    15.0         0.039788            377.0   NaN
# 1    64.0    57.0         0.009854             52.0   NaN
# 2    32.0    61.0         0.001797             16.0   NaN
# 3    48.0    20.0         0.002815             15.0   NaN
# 4    16.0     7.0         0.024036            139.0   NaN
#
#   suggest_autocomplete_boosted thumbnail
# 0                          NaN       NaN
# 1                          NaN       NaN
# 2                          NaN       NaN
# 3                          NaN       NaN
# 4                          NaN       NaN
#
# [5 rows x 105 columns]

# %%
df[['title','image_id']].tail(5)
# Out:
#                                         title  \
# 100352                   Palais du Luxembourg
# 100353  Avenue de l'Observatoire (Luxembourg)
# 100354                    Le Panthéon a Paris
# 100355           Palais de la Bourse, a Paris
# 100356                       Porte St. Martin
#
#                                     image_id
# 100352                                   NaN
# 100353  53dd3d22-98b2-aad9-1031-761bb185403e
# 100354                                   NaN
# 100355                                   NaN
# 100356                                   NaN

# %%
# testing getting image files
# https://www.artic.edu/iiif/2/{identifier}/{region}/{size}/{rotation}/{quality}.{format}
# La Grande Jatte
url = 'https://www.artic.edu/iiif/2/53dd3d22-98b2-aad9-1031-761bb185403e/full/843,/0/default.jpg'
r = requests.get(url).content

# %%
# using hte image package to get the image from the link
image = Image.open(BytesIO(r))
image.save("Resources/image.jpg")
